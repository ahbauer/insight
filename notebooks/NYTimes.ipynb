# %%
# coding:utf-8
import os
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import pandas
import seaborn
import pymysql as mdb
import re
import time
import json
import nltk
from bs4 import BeautifulSoup
import requests
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import cPickle as pickle
import datetime

# %%
(article_dates_imm,article_sents_imm) = pickle.load(open('/Users/bauer/insight/teleborder/data/nytimes/immigration/sentiment_data_afinn.txt', 'r'))
(article_dates_econ,article_sents_econ) = pickle.load(open('/Users/bauer/insight/teleborder/data/nytimes/sentiment_data_freq2.txt', 'r'))
article_sents_imm = np.array(article_sents_imm)
article_sents_econ = np.array(article_sents_econ)
print len(article_dates_imm)
print len(article_sents_econ)
# Out:
# 28901
# 16734

# %%
plt.plot(article_dates,article_sents, '.')

# %%
dates_imm = [datetime.datetime.combine(d, datetime.datetime.min.time()) for d in article_dates_imm]
sentiments_imm = pandas.Series(article_sents_imm, index=dates_imm)
dates_econ = [datetime.datetime.combine(d, datetime.datetime.min.time()) for d in article_dates_econ]
sentiments_econ = pandas.Series(100.*article_sents_econ, index=dates_econ)
print len(dates_imm)
print len(dates_econ)
# Out:
# 28901
# 16734

# %%
# sentiments_month = sentiments.resample("M")
# sentiments_month.plot()
sentiments_month_imm = sentiments_imm.resample("M")
sentiments_month_imm.plot()
sentiments_month_econ = sentiments_econ.resample("M")
sentiments_month_econ.plot()

# %%
words = [w.lower().decode('utf-8') for w in tokens]
words = [i for i in words if i not in stop]
print words
# Out:
# [u'monday', u':', u'december', u'auto', u'salesanalysts', u'expect', u'december', u'vehicle', u'sales', u'united', u'states', u'automakers', u'report', u'numbers', u'monday', u',', u'possibly', u'yielding', u'highest', u'december', u'total', u'since', u'2006', u'.', u',', u'2014', u'set', u'one', u'industrys', u'successful', u'years', u'time', u',', u'low', u'gas', u'prices', u'surging', u'demand', u'sport', u'utility', u'vehicles', u'powered', u'sales', u'analysts', u'estimate', u'could', u'reach', u'nearly', u'17', u'million', u'vehicles', u'nationwide.for', u'second', u'year', u'row', u',', u'small', u's.u.v.s', u'fastest', u'growing', u'area', u'american', u'buyers', u',', u'according', u'kelley', u'blue', u'book', u',', u'full-size', u'trucks', u'expected', u'top', u'two', u'million', u'sold', u'first', u'time', u'since', u'2007', u'.', u'automakers', u'also', u'dealt', u'safety', u'problems', u'year', u'resulted', u'60', u'million', u'vehicles', u'recalled', u'nationwide', u'on
# ...

# %%
stemmed = []
for word in words:
    stemmed.append(stemmer.stem(word))
print stemmed
# Out:
# [u'monday', u':', u'decemb', u'auto', u'salesanalyst', u'expect', u'decemb', u'vehicl', u'sale', u'unit', u'state', u'automak', u'report', u'number', u'monday', u',', u'possibl', u'yield', u'highest', u'decemb', u'total', u'sinc', u'2006', u'.', u',', u'2014', u'set', u'one', u'industri', u'success', u'year', u'time', u',', u'low', u'gas', u'price', u'surg', u'demand', u'sport', u'util', u'vehicl', u'power', u'sale', u'analyst', u'estim', u'could', u'reach', u'near', u'17', u'million', u'vehicl', u'nationwide.for', u'second', u'year', u'row', u',', u'small', u's.u.v.', u'fastest', u'grow', u'area', u'american', u'buyer', u',', u'accord', u'kelley', u'blue', u'book', u',', u'full-siz', u'truck', u'expect', u'top', u'two', u'million', u'sold', u'first', u'time', u'sinc', u'2007', u'.', u'automak', u'also', u'dealt', u'safeti', u'problem', u'year', u'result', u'60', u'million', u'vehicl', u'recal', u'nationwid', u'one', u'everi', u'five', u'road', u'.', u'aaron', u'm.', u'kessler', u'['
# ...

# %%
# Out:
# Ignoring the word na�ve.
# [u'a+', u'abound', u'abound', u'abund', u'abund', u'access', u'access', u'acclaim', u'acclaim', u'acclam']
# [u'2-face', u'2-face', u'abnorm', u'abolish', u'abomin', u'abomin', u'abomin', u'abomin', u'abort', u'abort']

# %%
score = 0
count = 0
for word in stemmed:
    if word in positive_stemmed:
        score += 1
        count += 1
    if word in negative_stemmed:
        score -= 1
        count += 1

print 'Score = {0}, Count = {1}'.format(score, count)
# Out:
# Score = 2, Count = 40
